# %%
#example
name = "sankar"    ***** Alphabet         ****  String            *****  str     
age = 40           **** Whole number      ***** Integer          ****** int
height = 6.0       ***** Decimal value    ****  Floating value   ****   float

# %%
Data Types of PYTHON 

numeric     ****   int, float, complex,  a+bj     10+5j  ******
string      ****Alphabet    *****
list 
tubles
dictionery
set

# %%
#input() function

name = input("enter your name:")
age = input("enter your age:")
height =input("enter your height:")
# Out:
# enter your name: sankar
# enter your age: 56
# enter your height: 175

# %%
print(age)
print(name)
print(height)
# Out:
# 56
# sankar
# 175

# %%
#type() function
type(name)
# Out:
# str

# %%
type(age)
# Out:
# str

# %%
type(height)
# Out:
# str

# %%
age=age+3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 age=age+3
#
# TypeError: can only concatenate str (not "int") to str

# %%
#datatype convertion
age=int(input("enter your age:"))
# Out:
# enter your age: 56

# %%
type(age)
# Out:
# int

# %%
age=age+3
print(age)
# Out:
# 59

# %%
height=int(input("entr your height:"))
# Out:
# entr your height: 185

# %%
type(height)
# Out:
# int

# %%
#printing variables.
print(name)
print(age)
print(height)
# Out:
# sankar
# 59
# 185

# %%
print(name,age,height)
# Out:
# sankar 59 185

# %%
print("your name is :" ,name)
print("your age is :" , age)     
print("your height is :" , height)
# Out:
# your name is : sankar
# your age is : 59
# your height is : 185

# %%
print(f"the name is {name} your age is {age} your height is {height}")
# Out:
# the name is sankar your age is 59 your height is 185

# %%
#input function
#type()function
